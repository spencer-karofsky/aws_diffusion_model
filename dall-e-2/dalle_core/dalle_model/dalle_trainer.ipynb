# %% [markdown]
# # Train DALL·E 2

# %% [markdown]
# Description
# * Contains the script to train DALL·E 2
#
#
# Usage
# * Run this notebook directly
#
#
# Author
# * Spencer Karofsky (https://github.com/spencer-karofsky)

# %%
import importlib.util
import sys
import os

# Step 1: Point to the file
dalle_path = '/Users/spencerkarofsky/Desktop/projects/aws_diffusion_model/dall-e-2/dalle_core/dalle_model/dalle_2.py'

# Step 2: Load the module from file (despite relative imports inside it)
spec = importlib.util.spec_from_file_location("dalle_core.dalle_model.dalle_2", dalle_path)
dalle_module = importlib.util.module_from_spec(spec)
sys.modules["dalle_core.dalle_model.dalle_2"] = dalle_module
spec.loader.exec_module(dalle_module)

# Step 3: Extract class
DALLE2 = dalle_module.DALLE2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 12
#      10 dalle_module = importlib.util.module_from_spec(spec)
#      11 sys.modules["dalle_core.dalle_model.dalle_2"] = dalle_module
# ---> 12 spec.loader.exec_module(dalle_module)
#      14 # Step 3: Extract class
#      15 DALLE2 = dalle_module.DALLE2
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/Desktop/projects/aws_diffusion_model/dall-e-2/dalle_core/dalle_model/dalle_2.py:46
#      43 from torch.utils.data import DataLoader
#      44 from typing import List
# ---> 46 from ..prior.dalle_2_prior import DiffusionPrior
#      47 from ..decoder.dalle_2_decoder import Decoder
#      48 from ..clip.clip_embedder import CLIPEmbedder
#
# ...
