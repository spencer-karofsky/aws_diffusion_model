# %% [markdown]
# # Data Curation and Basic Preprocessing

# %% [markdown]
# #### Spencer Karofsky

# %%
from torchvision import transforms
from dataset_utils import MidjourneyDataset, COCODataset

my_transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
])

# Midjourney
# dataset = MidjourneyDataset(save_dir='local_datasets/midjourney', transform=my_transform)
dataset = COCODataset(
    save_dir='local_datasets/coco',
    categories='dog',
    transform=my_transform,
    max_images=1000
)

# %%
dataset.download()
# Out:
# COCO dataset already downloaded and processed. Skipping.
