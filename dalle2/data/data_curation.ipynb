# %% [markdown]
# # Data Curation and Basic Preprocessing

# %% [markdown]
# #### Spencer Karofsky

# %%
import pandas as pd

df = pd.read_parquet("hf://datasets/CortexLM/midjourney-v6/data/train-00000-of-00001.parquet")
print(df.columns)
print(df.head(3))
# Out:
# Index(['prompt', 'image_url', 'timestamp'], dtype='object')
#                                               prompt  \
# 0  A young child is sitting on some pita bread ne...
# 1  A baby is chewing on a lawn chair, while a dog...
# 2   That city skyline with a blow dryer a cord on it
#
#                                            image_url                 timestamp
# 0  https://f004.backblazeb2.com/file/sota-images/... 2024-04-25 07:25:25+00:00
# 1  https://f004.backblazeb2.com/file/sota-images/... 2024-04-25 07:24:06+00:00
# 2  https://f004.backblazeb2.com/file/sota-images/... 2024-04-25 07:23:29+00:00

# %%
from torchvision import transforms
from dataset_utils import MidjourneyDataset, COCODataset

my_transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
])

# Midjourney
dataset = COCODataset(
    save_dir='local_datasets/coco',
    categories='dog',
    transform=my_transform,
    max_images=1000
)

# %%
dataset.download()
# Out:
# Downloading COCO val2017 images...
# Downloading COCO annotations...
# loading annotations into memory...
# Done (t=0.20s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Building metadata...
# Total captioned images in COCO: 5000
# Filtering captions by keyword: 100%|██████████| 5000/5000 [00:00<00:00, 243925.79it/s]
# Found 205 images with captions matching keywords.
